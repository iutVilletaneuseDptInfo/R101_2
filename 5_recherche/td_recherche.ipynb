# %% [markdown]
# # <center> TD 5 : Algorithmes de recherche

# %% [markdown]
# ## Exercice 1 : Recherche séquentielle*
#
# Les deux fonctions ci-dessous implémentent la recherche séquentielle
# d’un caractère dans une chaîne. Elles fonctionnent aussi pour la
# recherche d'un élément dans une liste.

# %%
#Version 1
def appartient1(caractere, ch):
    i = 0
    rep = False
    while i < len(ch):
        if ch[i] == caractere:
            rep = True
        i += 1
    return rep


#Version 2
def appartient2(caractere, ch):
    i = 0
    rep = False
    while i < len(ch) and not rep:
        if ch[i] == caractere:
            rep = True
        i += 1
    return rep


car = "a"
ch = "Super, c'est parfait !"
if appartient1(car, ch):
    print("Le caractère", car, "est dans la chaîne", ch)
else:
    print("Le caractère", car, "n'est pas dans", ch)

# %% [markdown]
# - Combien de comparaisons (entre caractères) sont effectuées par chaque fonction pour chercher le caractère `"a"`
#     - dans la chaîne `"bbbba"` ?
#     - dans la chaîne `"bbabb"` ?
#     - dans la chaîne `"abbbb"` ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 2 : Inclusion*
#
# - Définir une fonction `inclus` prenant en paramètres deux chaînes de caractères `ch1`et `ch2` et retournant
#     - `True` si tous les caractères de la chaîne `ch1` sont inclus dans la chaîne `ch2`
#     - et `False` sinon.
#
# **Remarque** : Il peut être utile d'utiliser une des fonctions `appartient` de l'Exercice 1.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# - Quelle est la complexité  dans le pire des cas de cette fonction ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 3 : Recherche par dichotomie*
#
# On consière le tableau trié de 17 nombres triés :

# %% [markdown]
# ```
# tab = [10, 13, 19, 28, 29, 32, 34, 37, 39, 42, 48, 49, 72, 81, 86, 93, 96]
# ```

# %% [markdown]
# - Appliquer à la main l’algorithme de recherche par dichotomie (rappelé ci-dessous) pour chercher le nombre `19`dans `tab`.
#     - Faire un tableau d’évolution des variables `debut`, `milieu` et `fin`.
#     - Combien d'itérations sont faites par l'algorithme ?

# %%
def recherche_dt(element, tab):
    debut = 0
    fin = len(tab) - 1
    while debut <= fin:
        milieu = (debut + fin) // 2

        if element == tab[milieu]:  # on a trouvé l'élément
            return milieu
        elif element < tab[milieu]:
            fin = milieu - 1  # on prend la moitié gauche
        else:
            debut = milieu + 1  # on prend la moitié droite
    return -1

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# - Faire de même pour le nombre `20`.

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 4 : Inclusion avec des chaînes triées**
#
# Définir une fonction `inclus2` prenant en paramètres deux chaînes
# de caractères `ch1` et `ch2` **triées dans l'ordre alphabétique**  et renvoyant
# - `True` si tous les caractères de la chaîne `ch1`  sont inclus
# dans la chaîne `ch2`,
# - et `False` sinon,
#
# en utilisant le fait que les chaînes sont triées pour obtenir de meilleure performance que celles de l'algorithme de l'Exercice 2.

# %%
############################## 
#   Saisir votre code ici.   #
##############################
