# %% [markdown]
# # <center> TP 5 : Algorithmes de recherche

# %% [markdown]
# ## Exercice 1 : Le jeu du devin**
#
# Programmer le jeu du devin dont les règles sont les suivantes :
# - Vous choisissez (mentalement) un nombre entre 1 et 100,
# - Le devin (c'est-à-dire l'ordinateur) doit le trouver en un minimum d'essais.
# - À chaque essai, l'ordinateur propose un nombre et vous devez lui  indiquer (sans tricher !)
#     - s'il a trouvé (le programme se termine alors),
#     - si votre nombre est plus grand que le nombre proposé,
#     - ou si votre nombre est plus petit que le nombre proposé.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# * Combien d'essais faut-il *au minimum* à l'ordinateur pour trouver le nombre ?
# * Combien d'essais faut-il *au maximum* à l'ordinateur pour trouver le nombre ?
# * Combien d'essais faut-il au maximum à l'ordinateur pour trouver un nombre entre 1 et 1000 ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 2 : Mêmes caractères*
#
# ### Question 1
#
# - Définir la fonction `memes_caracteres` prenant en paramètres deux chaînes `ch1` et `ch2` et renvoyant
#     - `True` si elles comportent les mêmes caractères
# (tout caractère de l'une apparaît dans l'autre, mais pas nécessairement avec la même fréquence),
#     - et `False` sinon.
#
# *Indication* : On pourra utiliser la fonction `inclus` définie dans le TD 5 et rappelée ci-dessous.

# %%
def appartient(caractere, ch):
    i = 0
    rep = False
    while i < len(ch) and not rep:
        if ch[i] == caractere:
            rep = True
        i += 1
    return rep


def inclus(ch1, ch2):
    i = 0
    n = len(ch1)
    while i < n:
        if not appartient(ch1[i], ch2):
            return False
        i += 1
    return True

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 2
#
# - Définir la fonction `memes_caracteres_trie` prenant en paramètres deux chaînes de caractères **triées** `ch1` et `ch2` et renvoyant
#     - `True` si elles comportent les mêmes caractères (tout caractère de l'une apparaît dans l'autre, mais pas nécessairement avec la même fréquence),
#     - et `False` sinon.
#
# *Indication* : On ne parcourera qu'une seule fois chacune des deux chaînes en avançant parallèlement dans les deux chaînes.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ### Question 3
#
# Quelle est la complexité dans le pire des cas de chacune de ces fonctions ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 3 : Calcul d'une racine carrée***
#
# Soit une fonction mathématique $f$ continue et strictement
# monotone (comme la racine carrée). Si $f(a)$ et $f(b)$ sont de
# signe différent (soit $f(a) \times f(b) ≤ 0$), le **théorème des
# valeurs intermédiaires** garantit l’existence d’un nombre $x$ tel
# que $f(x) = 0$ sur l’intervalle $[a,b]$.
#
# On peut rechercher ce nombre par dichotomie, de manière approchée :
#
# - On calcule $c = (a+b)/2$ et $f(c)$.
# - Si $f(a) \times f(c) ≤ 0$, la solution $x$ appartient à
# l’intervalle $[a,c]$ ; sinon elle appartient à l’intervalle $[c,b]$.
# - Dans le premier cas, on remplace $b$ par $c$ ; dans le second,
# on remplace $a$ par $c$.
#
# On répète ces étapes tant que la longeur de l’intervalle est
# supérieure à une précision $\epsilon$ donnée.
# La valeur de $c$ approchera alors la solution de $f(x)=0$ à
# $\epsilon/2$ près.
#
# - Définir une fonction calculant de manière approchée (erreur inférieure à $10^{-5}$) la racine carrée d'un nombre $n$. Pour cela, on cherchera la solution de la fonction $f(x) = 0$ où $f(x) = x^2 -n$.

# %%
############################## 
#   Saisir votre code ici.   #
##############################
