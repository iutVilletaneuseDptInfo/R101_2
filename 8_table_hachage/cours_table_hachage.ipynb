# %% [markdown]
# # <center>  Cours : Tables de hachage

# %% [markdown]
# Dans ce chapitre, on présente une nouvelle structure de données : *les tables de hachage* qui permettent une association clé-valeur.
#
# Les tables de hachage servent en particulier à stocker un ensemble de valeurs (sans qu'elles soient ordonnées) en permettant de très rapidement :
# - savoir si une valeur est ou non dans la table,
# - ajouter/supprimer rapidement des valeurs dans la table.
# en cherchant/ajoutant la valeur à l'emplacement de la table correspondant au résultat d'une *fonction de hachage* calculée en $\mathcal{O}(1)$ (temps constant).

# %% [markdown]
# Un **tableau trié** est une structure de données permettant de déterminer rapidement si une valeur appartient à un ensemble (grâce à la recherche dichotomique dont la complexité est logarithmique en la taille du tableau). En revanche, ajouter/supprimer des valeurs n'est pas efficace car il faut maintenir le tableau trié.
#
# Un **tableau non nécessairement trié** (*i.e*, ne prenant pas en compte un ordre sur les éléments) permet d'ajouter/supprimer rapidement des éléments mais la recherche d'un élément dans le tableau n'est pas rapide (avec une recherche séquentielle dont la complexité est linéaire).
#
# Les tables de hachage permettent (sous certaines conditions) d'avoir les deux propriétés simultanément.
#
# **Remarque :** Les dictionnaires en python sont des tables de hachage (il s'agit d'une version plus générale des tables de hachage que celle présentée dans ce chapitre).

# %% [markdown]
# ## Principe

# %% [markdown]
# On souhaite stocker l'ensemble de nombres suivant :
#
# 12, 45, 34, 67, 78, 345, 7069, 59482, 4, 2, 34534, 57, 3321, 23, 543, -12, 847, -342, 897, 0, -1
#
# Si l'on stocke cet ensemble sous la forme d'un tableau :

# %%
tab = [12, 45, 34, 67, 78, 345, 7069, 59482, 4, 2, 34534, 57, 3321, 23, 543, 18, 847, 342, 897, 0, 1]

# %% [markdown]
# alors savoir si un nombre est dans mon tableau nécessite de le comparer à 21 valeurs dans le pire des cas.
#
# Si l'on sépare les nombres pairs et impairs en deux tableaux distincts :

# %%
pairs = [12, 34, 78, 59482, 4, 2, 34534, 18, 342, 0]
impairs = [ 45, 67, 345, 7069, 57, 3321, 23, 543, 847, 897, 1]

# %% [markdown]
# savoir si une valeur est l'ensemble nécessite alors au plus 10 comparaisons si la valeur est paire, et 11 comparaisons si la valeur est impaire.
#
# On peut même faire mieux en séparant les nombres selon leur dernier chiffre.

# %%
fini_par_0 = [0]
fini_par_1 = [3321, 1]
fini_par_2 = [12, 59482, 2, 342]
fini_par_3 = [23, 543]
fini_par_4 = [34, 4, 34534]
fini_par_5 = [45, 345]
fini_par_6 = []
fini_par_7 = [67, 57, 847, 897]
fini_par_8 = [78, 18]
fini_par_9 = [7069]

# %% [markdown]
# Dans ce cas, pour déterminer si 97047 appartient à l'ensemble, il suffit de chercher si ce nombre est dans la liste des nombres se terminant par 7. Il faut donc chercher parmi 4 valeurs (et non plus 21).
# Dans cet exemple, la recherche d'un nombre nécessite  au plus 4 comparaisons.

# %% [markdown]
# La recherche est plus rapide mais requiert 10 tableaux. Pour implanter efficacement cette stratégie, on utilise une structure de données imbriquée : on crée une variable `table` qui correspond à un tableau de 10 cases. Pour tout indice `i` (entre 0 et 9), `table[i]` est un tableau contenant l'ensemble des nombres se terminant par le chiffre `i`.
#
# De cette manière, les 10 tableaux précédents sont stockés sous la forme :

# %%
table = [
    [0],
    [3321, 1],
    [12, 59482, 2, 342],
    [23, 543],
    [34, 4, 34534],
    [45, 345],
    [],
    [67, 57, 847, 897],
    [78, 18],
    [7069]
]

# %% [markdown]
# On peut alors coder des fonctions pour chercher si un entier apparaît dans la table, ajouter des entiers dans la table ou en supprimer.
#
# **Remarque :**
# - Si `entier` est un entier positif,  `entier % 10` permet de connaître le dernier chiffre du nombre `entier`et donc son indice dans la table. - Si `entier` est un entier négatif, on obtient son dernier chiffre avec l'instruction `-entier % 10`.
# - Autrement dit, de manière plus compacte `abs(entier)%10` (où `abs` est la fonction valeur absolue) permet de determiner ce dernier chiffre.

# %% [markdown]
# * **Sur ce thème :** Exercice 1, TD 7

# %% [markdown]
# ## Fonctions de hachage

# %% [markdown]
# Si l'exemple précédent est efficace quand on a une petite liste des nombres, il pose cependant quelques **problèmes** :
# - si le **nombre de valeurs à stocker est très grand** (par exemple 100 000), alors chaque case de la table va contenir en moyenne 10 000 entiers. La recherche d'une valeur nécessitera jusqu'à 10 000 comparaisons ce qui n'est pas efficace. Pour améliorer la recherche, il faudrait pouvoir faire la même chose avec une table ne contenant plus 10 cases mais 10 000 voire 100 000 cases, et faire en sorte que chacune des cases ne contienne que très peu d'entiers ;
# - si l'on doit stocker **uniquement des multiples de 10**, alors tous les nombres seront dans `table[0]`, les autres cases ne contenant alors que des tableaux vides. La table est aussi peu performante pour la recherche qu'un tableau non trié ;
# - si l'on veut stocker des **valeurs non entières**, il faut procéder autrement pour séparer les valeurs.

# %% [markdown]
# L'utilisation des fonctions de hachage permet de pallier ces différents problèmes.

# %% [markdown]
# ### Principe d'une fonction de hachage
#
# Une *fonction de hachage* est une fonction prenant en paramètre une valeur et lui associant un entier. Elle doit respecter les conditions suivantes :
# - être très rapide à calculer (en temps constant),
# - bien distribuer/disperser les valeurs (autrement dit, limiter les collisions).
#
# Pour n'importe quelle valeur, l'entier retourné par la fonction de hachage **modulo la taille de la table** correspond alors à l'indice de la case du tableau dans laquelle la valeur doit être stockée.
#
# Avec la fonction de hachage, on peut déterminer dans quelle case de la table chercher : l'indice de la valeur `val` sera donné par `hachage(val)%len(table)`.

# %% [markdown]
# #### Exemple : Hachage de chaînes selon la somme des codes ASCII de leurs caractères.
# Pour créer une table de hachage contenant des chaînes de caractères, il faut concevoir une fonction de hachage qui associe à chaque chaîne de caractères un entier. On peut par exemple choisir d'additionner les codes ASCII des caractères formant la chaîne.
#
# *Rappel* : L'instruction `ord(car)` permet de connaître le code ASCII du caractère `car`.

# %%
def hachage(val):
    val = str(val) # pour hacher des valeurs qui ne sont pas des chaînes de caractères
    nombre = 0
    i = 0
    while i < len(val):
        nombre += ord(val[i])
        i += 1
    return nombre

# Exemples
print("hachage de a : ", hachage("a"))
print("hachage de b : ", hachage("b"))
print("hachage de bonjour : ", hachage("bonjour"))
print("Avec cette fonction, les anagrammes ont la même valeur de hachage.")
print("hachage de ab : ", hachage("ab"))
print("hachage de ba : ", hachage("ba"))
# Out:
# hachage de a :  97
# hachage de b :  98
# hachage de bonjour :  767
# Avec cette fonction les anagrammes ont la même valeur de hachage.
# hachage de ab :  195
# hachage de ba :  195

# %% [markdown]
# ## Notions de performances

# %% [markdown]
# L'efficacité de la recherche, de l'ajout et de la suppression dépend grandement du nombre de valeurs contenues dans une même case de la table. Si l'on note $c$ le nombre maximal de valeurs dans une même case de la table, alors la recherche, l'ajout et la suppression se font en $\mathcal{O}(c)$.
#
# Idéalement, on cherche à avoir une table de hachage très grande avec des valeurs bien réparties dans les différentes cases de manière à avoir une valeur petite pour $c$.
#
# **Remarques :**
#
# * La valeur $c$ dépend directement de la fonction de hachage. Le choix de la fonction de hachage a donc une grande influence sur l'efficacité de la table de hachage.
#
#   Une fonction de hachage *parfaite* répartit uniformément les différentes valeurs dans les cases de la table (même nombre de valeurs dans chaque case de la table).
# <BR>
#
# * La valeur de $c$ varie au cours des ajouts/suppressions. Au départ, quand la table est vide, elle vaut 0. Dans le pire des cas, elle est égale au nombre de valeurs dans la table (si toutes les valeurs sont rangées dans la même case).
# <BR>
#
# * La dimension de la table est importante pour l'efficacité. Même si la fonction de hachage est *parfaite*, $c \geq \frac{n}{k}$ où $n$ est le nombre de valeurs dans la table et $k$ le nombre de cases de la table.
#
#   Il faut donc avoir une table avec suffisamment de cases par rapport au nombre de valeurs à stocker, quitte à recopier une table de hachage dans une autre plus grande.

# %% [markdown]
# * **Sur ce thème :** Exercice 2, TD 7
