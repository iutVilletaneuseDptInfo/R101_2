# %% [markdown]
# # Tableaux équitables
#
# Un tableau d'entiers est dit équitable s'il existe un nombre $k$ tel que pour tout chiffre de 0 à 9, le nombre d'entiers dans le tableau terminant par ce chiffre est 0 ou $k$. Par exemple, `[31, 42, -51, 92]` est équitable car il y a deux nombres terminant par 1 et deux nombres terminant par 2 (et 0 terminant par 3, 4, ..., 9). De même, `[564, 432, 4, 32, 99, 69, 72, 84, 19]` est équitable alors que `[33, 52, 98, 77, 42, 35, 63]` ne l'est pas car il y a deux nombres terminant par 3 et un seul terminant par 8.

# %% [markdown]
# ## Question 1
#
# Définir la fonction `nb_termine_par(tab, chiffre)` prenant en paramètre un tableau d'entiers **positifs** et un chiffre et retournant le nombre d'entiers contenant ce chiffre.
#
# *Rappel :* pour avoir le dernier chiffre d'un entier **positif** : `nb%10`

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 2
#
# Quelle est la complexité asymptotique dans le pire cas de `nb_termine_par` ? Justifier rapidement.

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Question 3
#
# Définir la fonction `est_equitable` prenant en paramètre un tableau et retournant `True` si celui-ci est équitable, et `False` sinon.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 4
#
# Définir une fonction de tests unitaires pour la fonction `est_equitable`.

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Question 5
#
# Quelle est la complexité asymptotique de la fonction `est_equitable` dans le pire cas ? Justifier rapidement.

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.
